# %% [markdown]
# #### USA Population Map using Folium package

# %%
import folium
from faker import Faker
import pandas as pd
import random

# Create a function to generate a synthetic dataset with location data using Faker
def generate_synthetic_data():
    fake = Faker()
    data = {
        'City': [fake.city() for _ in range(50)],
        'State': [fake.state() for _ in range(50)],
        'Latitude': [random.uniform(24, 49) for _ in range(50)],  # USA latitude range
        'Longitude': [random.uniform(-125, -66) for _ in range(50)],  # USA longitude range
        'Population': [random.randint(10000, 1000000) for _ in range(50)]
    }
    return pd.DataFrame(data)

# Generate synthetic data
df = generate_synthetic_data()

# Save the dataset with missing values filled to a new CSV file
df.to_csv('us_population.csv', index=False)

# %%
df.head()
# Out:
#               City       State   Latitude   Longitude  Population
# 0  Lake Frankville  California  36.486998  -76.080289      835320
# 1    Schneiderfurt  Washington  38.711111  -88.126887      723149
# 2       North Judy       Maine  38.976015 -118.967563      517216
# 3    Frederickstad  California  35.974427 -118.731445      452226
# 4   Lake Tracyberg      Nevada  34.436998 -124.098815      645947

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        50 non-null     object
#  1   State       50 non-null     object
#  2   Latitude    50 non-null     float64
#  3   Longitude   50 non-null     float64
#  4   Population  50 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#         Latitude   Longitude     Population
# count  50.000000   50.000000      50.000000
# mean   38.148453  -95.269119  578432.080000
# std     6.724395   16.526145  276339.224814
# min    25.916090 -124.184199   12680.000000
# 25%    33.650033 -110.007841  378437.500000
# 50%    37.275494  -93.002984  624556.500000
# 75%    44.038065  -85.097145  771022.750000
# max    48.822085  -66.208093  985568.000000

# %%
# Create a map using Folium, centered around the USA
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers to the map
for idx, row in df.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=row['Population'] / 100000,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=f"City: {row['City']}<br>State: {row['State']}<br>Population: {row['Population']}",
    ).add_to(m)

# Save the map as an HTML file
m.save('usa_map_chart.html')

# Display the map in Jupyter Notebook (optional)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0d6bb2865c96c5eb85169380c11c556 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0d6bb2865c96c5eb85169380c11c556&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0d6bb2865c96c5eb85169380c11c556 = L.map(
#                 &quot;map_f0d6bb2865c96c5eb85169380c11c556&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_081ce889887ef4ae055820a1b21045ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0d6bb2865c96c5eb85169380c11c556);
#
#
#             var circle_marker_1b88654f09cee09b07a14ae5c8174dfb = L.circleMarker(
#                 [36.48699770632919, -76.08028860082868],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.3532, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f0d6bb2865c96c5eb85169380c11c556);
#
#
#         var popup_dde661dd8a8968cf5b16a166e76605ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_153b9cc6a76cf40da840c94f383630d2 = $(`&lt;div id=&quot;html_153b9cc6a76cf40da840c94f383630d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Lake Frankville&lt;br&gt;State: California&lt;br&gt;Population: 835320&lt;/div&gt;`)[0];
#                 popup_dde661dd8a8968cf5b16a166e76605ac.setContent(html_153b9cc6a76cf40da840c94f383630d2);
#
#
#
#         circle_marker_1b88654f09cee09b07a14ae5c8174dfb.bindPopup(popup_dde661dd8a8968cf5b16a166e76605ac)
#         ;
#
#
#
#
#             var circle_marker_d175df7f8643206dcee4f7fa9fc632e0 = L.circleMarker(
#                 [38.71111109903039, -88.12688716226042],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.23149, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f0d6bb2865c96c5eb85169380c11c556);
#
#
#         var popup_114cb652bce39aa915e033da807f751b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b59229e457a156cee31493cd040065a7 = $(`&lt;div id=&quot;html_b59229e457a156cee31493cd040065a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Schneiderfurt&lt;br&gt;State: Washington&lt;br&gt;Population: 723149&lt;/div&gt;`)[0];
#                 popup_114cb652bce39aa915e033da807f751b.setContent(html_b59229e457a156cee31493cd040065a7);
#
#
#
#         circle_marker_d175df7f8643206dcee4f7fa9fc632e0.bindPopup(popup_114cb652bce39aa915e033da807f751b)
#         ;
#
#
#
#
#             var circle_marker_42e8f5aca50e38ecb2fe01c8cfa8743b = L.circleMarker(
#                 [38.97601462055072, -118.96756348212382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.17216, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f0d6bb2865c96c5eb85169380c11c556);
#
#
#         var popup_7377b6b6868b2f482e91d8db5ae535a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_566de3a317cd77e631fb42086478a4c5 = $(`&lt;div id=&quot;html_566de3a317cd77e631fb42086478a4c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: North Judy&lt;br&gt;State: Maine&lt;br&gt;Population: 517216&lt;/div&gt;`)[0];
#                 popup_7377b6b6868b2f482e91d8db5ae535a7.setContent(html_566de3a317cd77e631fb42086478a4c5);
#
#
#
#         circle_marker_42e8f5aca50e38ecb2fe01c8cfa8743b.bindPopup(popup_7377b6b6868b2f482e91d8db5ae535a7)
#         ;
#
#
#
#
#             var circle_marker_5771b2e739a0b32ebbc278656c
